# %% [markdown]
# # Regresión polinómica

# %% [markdown]
# # Cómo importar las librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importar el data set

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/JuanMi-Galan/machinelearning-az/refs/heads/master/original/Part%202%20-%20Regression/Section%206%20-%20Polynomial%20Regression/Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values # Matriz 1:2
y = dataset.iloc[:, 2].values # Vector

# %% [markdown]
# # Dividir el data set en conjunto de entrenamiento y conjunto de testing

# %%
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)"""

# %% [markdown]
# # Escalado de variables

# %%
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)"""

# %% [markdown]
# # Ajustar la regresión lineal con el dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# #Ajustar la regresión polinomica con el data set

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4) # Regrecion Polinomica de grado 2 por defecto.
X_poly = poly_reg.fit_transform(X) # Variables independientes y sus tranformaciones.
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Visualización de los resultados del Modelo Lineal

# %%
plt.scatter(X, y, color = "red")
plt.plot(X, lin_reg.predict(X), color = "blue")
plt.title("Modelo de Regresión Lineal")
plt.xlabel("Posición del empleado")
plt.ylabel("Sueldo (en $)")
plt.show()

# %% [markdown]
# # Visualización de los resultados del Modelo Polinómico

# %%
X_grid = np.arange(min(X), max(X), 0.1) # Vector fila
X_grid = X_grid.reshape(len(X_grid), 1) # Vector columna
plt.scatter(X, y, color = "red")
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = "blue") #poly_reg.fit_transform(X_grid) o X_poly
plt.title("Modelo de Regresión Polinómica")
plt.xlabel("Posición del empleado")
plt.ylabel("Sueldo (en $)")
plt.show()
# Out:
# <ipython-input-59-2d75d185247f>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1) # Vector fila

# %% [markdown]
# # Predicción de nuestros modelos
# # Se ha añadido la sintaxis de doble corchete necesaria para hacer la predicción en las últimas versiones de Python (3.7+)

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
