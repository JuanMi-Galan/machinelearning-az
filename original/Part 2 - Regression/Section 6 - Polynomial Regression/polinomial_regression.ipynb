# %% [markdown]
# # Regresión polinómica

# %% [markdown]
# # Cómo importar las librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importar el data set

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/JuanMi-Galan/machinelearning-az/refs/heads/master/original/Part%202%20-%20Regression/Section%206%20-%20Polynomial%20Regression/Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values # Matriz 1:2
y = dataset.iloc[:, 2].values # Vector

# %% [markdown]
# # Dividir el data set en conjunto de entrenamiento y conjunto de testing

# %%
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)"""

# %% [markdown]
# # Escalado de variables

# %%
"""from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)"""

# %% [markdown]
# # Ajustar la regresión lineal con el dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Visualización de los resultados del Modelo Lineal

# %%
plt.scatter(X, y, color = "red")
plt.plot(X, lin_reg.predict(X), color = "blue")
plt.title("Modelo de Regresión Lineal")
plt.xlabel("Posición del empleado")
plt.ylabel("Sueldo (en $)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d9e206167b0f> in <cell line: 2>()
#       1 plt.scatter(X, y, color = "red")
# ----> 2 plt.plot(X, lin_reg.predict(X), color = "blue")
#       3 plt.title("Modelo de Regresión Lineal")
#       4 plt.xlabel("Posición del empleado")
#       5 plt.ylabel("Sueldo (en $)")
#
# NameError: name 'lin_reg' is not defined

# %% [markdown]
# # Visualización de los resultados del Modelo Polinómico

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color = "red")
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = "blue")
plt.title("Modelo de Regresión Polinómica")
plt.xlabel("Posición del empleado")
plt.ylabel("Sueldo (en $)")
plt.show()
# Out:
# <ipython-input-17-515fc1a5d534>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# # Predicción de nuestros modelos
# # Se ha añadido la sintaxis de doble corchete necesaria para hacer la predicción en las últimas versiones de Python (3.7+)

# %%
lin_reg.predict([[6.5]])
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2ede1c871857> in <cell line: 1>()
# ----> 1 lin_reg.predict([[6.5]])
#       2 lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
#
# NameError: name 'lin_reg' is not defined
